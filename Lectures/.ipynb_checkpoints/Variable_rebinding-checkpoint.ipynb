# %%
radius = 11
pi = 3

area = pi*(radius**2)
print(radius)
print(area)

radius = 14
print(radius)
#Since Python is sequential, we need to re run all vars cointaining the new value
print(area)
area = pi*(radius**2)
print(area)
# Out:
# 11
# 363
# 14
# 363
# 588
